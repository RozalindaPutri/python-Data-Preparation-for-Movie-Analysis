# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Kode Data Preparation for Movie Analysis.ipynb',
#  'movies_metadata.csv',
#  'ratings_small.csv']

# %%
movies_data = pd.read_csv("movies_metadata.csv")

# %%
movies_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   str
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  str
#  4   homepage               7779 non-null   str
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  str
#  7   original_language      45452 non-null  str
#  8   original_title         45463 non-null  str
#  9   overview               44509 non-null  str
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  str
#  12  production_companies   45460 non-null  str
#  13  production_countries   45460 non-null  str
#  14  release_date           45376 non-null  str
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  str
#  18  status                 45379 non-null  str
#  19  tagline                20412 non-null  str
#  20  title                  45460 non-null  str
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), float64(5), int64(2), str(15)
# memory usage: 37.6 MB

# %%
movies_data.sample(10)
# Out:
#        adult belongs_to_collection  budget  \
# 26446   True                   NaN       0
# 14678   True                   NaN       0
# 32603   True                   NaN       0
# 31276   True                   NaN  500000
# 25738   True                   NaN       0
# 4726    True                   NaN       0
# 12605   True                   NaN       0
# 10238   True                   NaN       0
# 35694   True                   NaN       0
# 1753    True                   NaN       0
#
#                                                   genres homepage     id  \
# 26446                     [{'id': 35, 'name': 'Comedy'}]      NaN  58012
# 14678  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN  89800
# 32603  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN  52764
# 31276  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  55012
# 25738                    [{'id': 37, 'name': 'Western'}]      NaN  72474
# 4726                 [{'id': 99, 'name': 'Documentary'}]      NaN  15559
# 12605                      [{'id': 18, 'name': 'Drama'}]      NaN  15957
# 10238  [{'id': 9648, 'name': 'Mystery'}, {'id': 10769...      NaN  32242
# 35694  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN  45098
# 1753   [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...      NaN  34582
#
#          imdb_id original_language       original_title  \
# 26446  tt0023943                en  The Devil's Brother
# 14678  tt0297905                ja                   害虫
# 32603  tt0847526                en           Sugarhouse
# 31276  tt0312612                en   Wolves In The Snow
# 25738  tt0043557                en           Fort Worth
# 4726   tt0109609                en     Destiny in Space
# 12605  tt1080695                da             Hvid nat
# 10238  tt0323630                ko                    폰
# 35694  tt1454545                ko        슬픔보다 더 슬픈 이야기
# 1753   tt0118785                nb         Budbringeren
#
#                                                 overview  ...  release_date  \
# 26446  The Devil's Brother or Bogus Bandits or Fra Di...  ...    1933-01-01
# 14678  13-year-old Sachiko is about to encounter the ...  ...    2001-03-16
# 32603  Tom is a middle-class city boy whose life has ...  ...    2007-08-24
# 31276  Wolves in the Snow begins with the news that A...  ...    2002-04-10
# 25738  Former gunfighter Ned Britt (Randolph Scott) s...  ...    1951-07-14
# 4726   Travel alongside the astronauts as they deploy...  ...    1994-01-17
# 12605  A psychological drama about Ulrich, a workahol...  ...    2007-10-26
# 10238  Soon after Ji-won gets a new cell phone, her f...  ...    2002-07-26
# 35694  K, a radio producer who loves a woman named Cr...  ...    2009-03-11
# 1753   Dimwitted, somewhat misanthropic Oslo mail car...  ...    1997-02-21
#
#       revenue runtime                                   spoken_languages  \
# 26446     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 14678     0.0    92.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 32603     0.0    90.0                                                 []
# 31276     0.0    90.0                                                 []
# 25738     0.0    80.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4726      0.0    40.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 12605     0.0   100.0             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 10238     0.0   100.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 35694     0.0   105.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 1753      0.0    83.0            [{'iso_639_1': 'nb', 'name': 'Bokmål'}]
#
#          status                                            tagline  \
# 26446  Released  In the early eighteenth century, Northern Ital...
# 14678  Released                                                NaN
# 32603  Released                                                NaN
# 31276  Released                                                NaN
# 25738  Released  RANDOLPH SCOTT as Fighting Editor Britt of the...
# 4726   Released                                                NaN
# 12605  Released                                                NaN
# 10238  Released                  The Last Call You'll Ever Get ...
# 35694  Released                        A Story Sadder Than Sadness
# 1753   Released                                                NaN
#
#                      title  video vote_average vote_count
# 26446  The Devil's Brother  False          6.5       14.0
# 14678       Harmful Insect  False          7.0        5.0
# 32603           Sugarhouse  False          6.6        5.0
# 31276   Wolves In The Snow  False          6.5        2.0
# 25738           Fort Worth  False          0.0        0.0
# 4726      Destiny in Space  False          7.0        2.0
# 12605          White Night  False          5.3        6.0
# 10238                Phone  False          6.3       36.0
# 35694       More Than Blue  False          6.9       21.0
# 1753             Junk Mail  False          5.7        6.0
#
# [10 rows x 24 columns]

# %%
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"])

# %%
movies_data["release_date"].dtypes
# Out:
# dtype('<M8[us]')

# %%
movies_data["status"].unique()
# Out:
# <ArrowStringArray>
# [       'Released',               nan,         'Rumored', 'Post Production',
#    'In Production',         'Planned',        'Canceled']
# Length: 7, dtype: str

# %%
movies_data["original_language"].nunique()
# Out:
# 89

# %%
#movies_data["status"] == "Released"

# %%
movies_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   str
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  str
#  4   homepage               7779 non-null   str
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  str
#  7   original_language      45452 non-null  str
#  8   original_title         45463 non-null  str
#  9   overview               44509 non-null  str
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  str
#  12  production_companies   45460 non-null  str
#  13  production_countries   45460 non-null  str
#  14  release_date           45376 non-null  datetime64[us]
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  str
#  18  status                 45379 non-null  str
#  19  tagline                20412 non-null  str
#  20  title                  45460 non-null  str
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), datetime64[us](1), float64(5), int64(2), str(14)
# memory usage: 37.2 MB

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
movies_data["profit"] = movies_data["revenue"] - movies_data["budget"]

# %%
movies_data["profit"].hist(bins = 100)
plt.title("Profit Movies Distribution")
plt.show()

# %%
movies_data["profit"].describe()
# Out:
# count    4.546000e+04
# mean     6.984491e+06
# std      5.214125e+07
# min     -1.657101e+08
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.550965e+09
# Name: profit, dtype: float64

# %%
import seaborn as sns

# %%
movies_data["profit"].plot(kind = "box")
# Out:
# <Axes: >

# %%
sns.boxplot(data = movies_data, x = "profit")
plt.show()

# %%
sns.boxplot(data = movies_data, x = "runtime")
plt.show()

# %%
movies_data["profit"].quantile(0.9)
# Out:
# np.float64(1578210.8999999824)

# %%
sns.scatterplot(data = movies_data,
                x = "runtime",
                y = "profit")
plt.show()

# %%
profitable_movies = movies_data[movies_data["profit"] > 0]

# %%
sns.scatterplot(data = profitable_movies,
                x = "runtime",
                y = "profit")
plt.show()

# %%
rating = pd.read_csv("ratings_small.csv")

# %%
rating_movies = rating.groupby("movieId", as_index = False)["rating"].median()

# %%
sns.histplot(data = rating_movies,
                x = "rating")
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
rating_movies["good_movies"] = rating_movies["rating"] >= 3

# %%
rating_movies["good_movies"].value_counts().plot(kind = "pie")
# Out:
# <Axes: >

# %%
new_df = movies_data.merge(rating_movies,
                        left_on = "id",
                        right_on = "movieId",
                        how = "inner")

# %%
sns.histplot(data = new_df,
             x = "profit",
             hue = "good_movies")
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
sns.scatterplot(data = new_df,
             x = "rating",
                y = "profit")
# Out:
# <Axes: xlabel='rating', ylabel='profit'>

# %%
new_df[["rating"]]
# Out:
#       rating
# 0       3.75
# 1       1.50
# 2       4.00
# 3       3.50
# 4       5.00
# ...      ...
# 2826    3.25
# 2827    4.00
# 2828    4.00
# 2829    4.00
# 2830    5.00
#
# [2831 rows x 1 columns]

# %%
new_df["original_language"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='original_language'>

# %%
new_df.select_dtypes(include = "number")
# Out:
#         budget     id  popularity      revenue  runtime  vote_average  \
# 0     60000000    949   17.924927  187436818.0    170.0           7.7
# 1     58000000    710   14.686036  352194034.0    130.0           6.6
# 2     98000000   1408    7.284477   10017322.0    119.0           5.7
# 3     52000000    524   10.137389  116112375.0    178.0           7.8
# 4     16500000   4584   10.673167  135000000.0    136.0           7.2
# ...        ...    ...         ...          ...      ...           ...
# 2826         0  80831    0.083371          0.0    121.0           6.5
# 2827         0   3104    2.302582          0.0     92.0           5.9
# 2828         0  64197    0.528657          0.0     97.0           6.0
# 2829         0  98604    0.803588          0.0     91.0           4.6
# 2830         0  49280    1.109068          0.0      1.0           6.5
#
#       vote_count       profit  movieId  rating
# 0         1886.0  127436818.0      949    3.75
# 1         1194.0  294194034.0      710    1.50
# 2          137.0  -87982678.0     1408    4.00
# 3         1343.0   64112375.0      524    3.50
# 4          364.0  118500000.0     4584    5.00
# ...          ...          ...      ...     ...
# 2826         2.0          0.0    80831    3.25
# 2827        33.0          0.0     3104    4.00
# 2828         5.0          0.0    64197    4.00
# 2829         6.0          0.0    98604    4.00
# 2830        22.0          0.0    49280    5.00
#
# [2831 rows x 10 columns]

# %%
def select_columns(df: pd.DataFrame, features: list,  target: list = "rating"):

  df = df.dropna().reset_index(drop = True)
  X = df[features]
  y = (df[target] >= 3).astype("int")

  return X, y

# %%
from sklearn.model_selection import train_test_split

# %%
features = ["budget", "popularity", "vote_average"]
X, y = select_columns(new_df, features = features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax.fit(X_train)
# Out:
# MinMaxScaler()

# %%
def scaling(df, scaler):

  # df["runtime	"] = df["runtime"].div(60)

  scaled_array = scaler.transform(df)
  scaled_df = pd.DataFrame(scaled_array, columns = scaler.get_feature_names_out())

  return scaled_df

# %%
X_train_scaled = scaling(X_train, minmax)
X_test_scaled = scaling(X_test, minmax)

# %%
X_test_scaled.iloc[0]
# Out:
# budget          0.500000
# popularity      0.042270
# vote_average    0.568182
# Name: 0, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
dt = DecisionTreeClassifier()

# %%
knn.fit(X_train_scaled, y_train)
dt.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred_knn = knn.predict(X_train_scaled)
y_train_pred_dt = dt.predict(X_train_scaled)

# %%
y_test_pred_knn = knn.predict(X_test_scaled)
y_test_pred_dt = dt.predict(X_test_scaled)

# %%
pd.crosstab(y_test, y_test_pred_knn)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       1  35

# %%
pd.crosstab(y_test, y_test_pred_dt)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       5  31
